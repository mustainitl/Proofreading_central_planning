# %%
import re
import json
import pdfplumber

pdf_path = "../input_files/BD01529397W_Tapu_2026-06-21_05-03-35PM.pdf"

extracted_texts = []

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        tables = page.extract_tables()

        for table in tables:
            for row in table:
                for cell in row:
                    if cell and cell.strip():
                        extracted_texts.append(cell.strip())

extracted_texts
# Out:
# ['body/gusset/corps/gousset/cuerpo/inserto/corpo/tassello/面料/内裆 57%\ncotton/coton/algodón/cotone/棉 38% modal/莫代尔 5% elastane/élasthanne/\nelastano/elastan/氨纶 elastic/élastique/banda elástica/elastico/松紧带 48%\npolyamide/poliamida/poliammide/锦纶 37% polyester/poliéster/poliestere/\n聚酯纤维 15% elastane/élasthanne/elastano/elastan/氨纶 exclusive of',
#  '2',
#  '3',
#  'SHORTIE/\nSHORTIE',
#  'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
#  '583-1B\n4',
#  '1',
#  'L | G | 170/80A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
#  'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
#  '583-1B\n4',
#  '1',
#  'M | 170/72A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
#  'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
#  '583-1B\n4',
#  '1',
#  'S | P | C H | 170/68A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
#  'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
#  '583-1B\n4',
#  '1',
#  'XL | XG | E G | 170/90A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
#  'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
#  '583-1B\n4',
#  '1',
#  'XS | XP | E CH | 165/64A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
#  'Substrate :',
#  'Front :',
#  'Back :',
#  'Finishing :',
#  'Dept :',
#  'Q1703R1-14mm White Recycle Ribbon NB-ITL Asia',
#  'PMS 218C PINK GOSSIP',
#  'PMS 218C PINK GOSSIP',
#  'Ultrasonic, Loop fold.',
#  'PFL']

# %%
['body/gusset/corps/gousset/cuerpo/inserto/corpo/tassello/面料/内裆 57%\ncotton/coton/algodón/cotone/棉 38% modal/莫代尔 5% elastane/élasthanne/\nelastano/elastan/氨纶 elastic/élastique/banda elástica/elastico/松紧带 48%\npolyamide/poliamida/poliammide/锦纶 37% polyester/poliéster/poliestere/\n聚酯纤维 15% elastane/élasthanne/elastano/elastan/氨纶 exclusive of',
 '2',
 '3',
 'SHORTIE/\nSHORTIE',
 'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
 '583-1B\n4',
 '1',
 'L | G | 170/80A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
 'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
 '583-1B\n4',
 '1',
 'M | 170/72A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
 'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
 '583-1B\n4',
 '1',
 'S | P | C H | 170/68A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
 'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
 '583-1B\n4',
 '1',
 'XL | XG | E G | 170/90A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
 'DEIJN decoration/sauf décoration/no incluye la decoración/\nesclusa la decorazione/装饰除外\nDEIJN RN54867 CA67359 ID# 36014990 416213-SPT 07 26\nDEIJN',
 '583-1B\n4',
 '1',
 'XS | XP | E CH | 165/64A\nmade in Bangladesh/fabriqué au Bangladesh/\nhecho en Bangladesh/fabbricato in Bangladesh/\n孟加拉制造',
 'Substrate :',
 'Front :',
 'Back :',
 'Finishing :',
 'Dept :',
 'Q1703R1-14mm White Recycle Ribbon NB-ITL Asia',
 'PMS 218C PINK GOSSIP',
 'PMS 218C PINK GOSSIP',
 'Ultrasonic, Loop fold.',
 'PFL']
