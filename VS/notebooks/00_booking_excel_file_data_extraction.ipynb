# %%
import pandas as pd
import openpyxl

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_excel("../input_files/excel_file.xlsx")

# %%
df
# Out:
#   Brand     Sector Silhouette Category  Sub-Category        Season  \
# 0   NaN        NaN        NaN      NaN           NaN           NaN
# 1  PINK  Intimates   BOYSHORT  Panties           NaN  Holiday 2026
#
#    Seasonless - Style Number  Image Designated Supplier (External)  \
# 0                        NaN    NaN                            NaN
# 1                 10240242.0    NaN                            MAS
#
#                                  Seasonless -  Is Seasonless  VSD Style#  \
# 0                                         NaN            NaN         NaN
# 1  10240242 PINK INTIMATES CODE BOYSHORT SP24            0.0    416213.0
#
#    Seasonless - Generic Article Seasonless - SAP Description  \
# 0                           NaN                          NaN
# 1                    11245830.0         PINK INTMTS CODE BOY
#
#   Seasonless - Generic Article Description  Carry Over  \
# 0                                      NaN         NaN
# ...

# %%
pd.reset_option("display.max_columns")

# %%
df = df[['Seasonless - Silhouette Code', 'Seasonless - Product Content Summary']]
df = df.dropna()
df
# Out:
#   Seasonless - Silhouette Code  \
# 1                      Shortie
#
#                 Seasonless - Product Content Summary
# 1  Panties & Swim Bottoms - (XXS - XXL) & O/S** (...

# %%
df.columns
# Out:
# Index(['Brand', 'Sector', 'Silhouette', 'Category', 'Sub-Category', 'Season',
#        'Seasonless - Style Number', 'Image', 'Designated Supplier (External)',
#        'Seasonless -', 'Is Seasonless', 'VSD Style#',
#        'Seasonless - Generic Article', 'Seasonless - SAP Description',
#        'Seasonless - Generic Article Description', 'Carry Over',
#        'Seasonless - Style Name', 'Seasonless - Status',
#        'Seasonless - Innovation Product', 'Seasonless - Innovation Protected',
#        'Product Sources', 'Unnamed: 21',
#        'Seasonless - Solids / Prints Care Codes',
#        'Seasonless - All Graphic / Foil Prints Care Codes',
#        'Seasonless - Diamante Care Codes', 'Seasonless - Wash Care Codes',
#        'Seasonless - Additional Packaging Requirements',
#        'Seasonless - Silhouette Code', 'Seasonless - Inseam Measurements',
#        'Seasonless - Care Label Text', 'Seasonless - Main Label Text',
#        'Seasonless - Care Label Exceptions',
# ...
